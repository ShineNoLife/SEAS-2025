# %% [markdown]
# ## Part 2:
#
# ### 2.1:
#
# ```python
# # From scratch
# def matrix_add(A, B):
#     C = [[0 for _ in range(len(A[0]))] for _ in range(len(A))]
#     for i in range(len(A)):
#         for j in range(len(A[0])):
#             C[i][j] = A[i][j] + B[i][j]
#
#     return C
#     pass
#
#
# # Test with A and another 2x3 matrix
# A = [[5, 2, 4], [1, 8, 6]]
# B = [[10, 20, 30], [40, 50, 60]]
#
# print("A + B (from scratch):", matrix_add(A, B))
#
# # NumPy
# print("A + B (NumPy):", np.array(A) + np.array(B))
# ```
#
# ### 2.2:
#
# ```python
# # From scratch
# def matrix_scalar_mul(A, d):
#
#     C = [[0 for _ in range(len(A[0]))] for _ in range(len(A))]
#     for i in range(len(A)):
#         for j in range(len(A[0])):
#             C[i][j] = A[i][j] * d
#
#     return C
#     pass
#
#
# # Test with A and another 2x3 matrix
# d = 3
# A = [[10, 20, 30], [40, 50, 60]]
# print("A + B (from scratch):", matrix_scalar_mul(A, 3))
#
# # NumPy
# print("A + B (NumPy):", np.array(A) * d)
# ```
#
# ### 2.3:
#
# ```python
# # From scratch
# def transpose(A):
#     C = [[0 for _ in range(len(A))] for _ in range(len(A[0]))]
#     for i in range(len(A)):
#         for j in range(len(A[0])):
#             C[j][i] = A[i][j]
#
#     return C
#     pass
#
# A = [[4, 1], [6, 2], [9, 6]]
# A_np = np.array(A)
# print("Transpose of A (from scratch):", transpose(A))
# print("Transpose of A (NumPy):\n", A_np.T)
# ```
#
# ### 2.4:
#
# ```python
# # From scratch
# def matmul(A, B):
#     C = [[0 for _ in range(len(B[0]))] for _ in range(len(A))]
#
#     for i in range(len(A)):
#         for j in range(len(B[0])):
#             for k in range(len(B)):
#                 C[i][j] += A[i][k] * B[k][j]
#
#     return C
#     pass
#
# A = [[4, 1], [6, 2], [9, 6]]
# B = [[10, 20, 30], [40, 50, 60]]
# A_np, B_np = np.array(A), np.array(B)
# print("A x B (from scratch):", matmul(A, B))
# print("A x B (NumPy):\n", np.dot(A_np, B_np))
# ```
#
#
# ### 2.5:
#
# ```python
# A = np.random.randint(0, 10, (2, 3))
# B = np.random.randint(0, 10, (3, 2))
#
# print("A:\n", A)
# print("B:\n", B)
#
# left_Term = (A @ B).T
# right_Term = B.T @ A.T
#
# print("Transpose of product property holds?")
# print("(AB)^T: ", left_Term)
# print("B^T A^T: ", right_Term)
# ```
#
#
# ## Part 3:
#
# ### 3.1:
#
# ```python
# # From scratch (lists)
# def linear_combination(v1, v2):
#     return [2*v1[i] - v2[i] for i in range(len(v1))]
#     pass
#
# v1 = [1, 2]
# v2 = [3, 4]
# print("2v1 - v2 (from scratch):", linear_combination(v1, v2))
#
# # Using NumPy
# v1_np = np.array(v1)
# v2_np = np.array(v2)
# print("2v1 - v2 (NumPy):", 2*v1_np - v2_np)
# ```
#
# ### 3.2:
#
# ```python
# # From scratch
# def apply_matrix(A, v):
#     C = [0 for _ in range(len(A))]
#     for i in range(len(A)):
#         for j in range(len(v)):
#             C[i] += A[i][j] * v[j]
#
#     return C
#     pass
#
# # Example: 90 degree rotation in 2D
# R = [[0, -1],
#      [1, 0]]
# v = [1, 1]
# print("Rotated vector (from scratch):", apply_matrix(R, v))
#
# # Using NumPy
# import numpy as np
# R_np = np.array(R)
# v_np = np.array(v)
# print("Rotated vector (NumPy):", R_np @ v_np)
# ```
#
# ```python
# A = [[1, 1, 0],
#      [1, 0, 1],
#      [0, 1, 1]]
#
# # Test the transformation on the basis vectors
# e1 = np.array([1, 0, 0])
# e2 = np.array([0, 1, 0])
# e3 = np.array([0, 0, 1])
#
# print("A @ e1 =", A @ e1)  # Should be [1, 1, 0]
# print("A @ e2 =", A @ e2)  # Should be [1, 0, 1]
# print("A @ e3 =", A @ e3)  # Should be [0, 1, 1]
#
# # Test the transformation on another vector, e.g., v = [2, 3, 4]
# v = np.array([2, 3, 4])
# print("A @ v =", A @ v)    # Should be [5, 6, 7]
# ```
#
#
# ### 3.3:
#
# ```python
# # From scratch
# def inner_product(u, v):
#     inner_product = 0
#     for i in range(len(u)):
#         inner_product += u[i] * v[i]
#
#     return inner_product
#     pass
#
# u = [1, 2, 3]
# v = [4, 5, 6]
# print("Inner product (from scratch):", inner_product(u, v))
#
# # Using NumPy
# u_np = np.array(u)
# v_np = np.array(v)
# print("Inner product (NumPy):", np.dot(u_np, v_np))
# ```
#
#
# ## Part 4:
#
# ### 4.1:
#
# ```python
# D = np.diag([2, 3, 4])
# k = 3
#
# # TODO: Fill in to verify the power property for diagonal matrices
# left = D**k
# right = np.diag([2**k, 3**k, 4**k])  # Diagonal matrix with elements raised to the power k
# print("Power property holds?", np.allclose(left, right)) # allclose checks if two matrices are equal
# ```
#
# ### 4.2:
#
# ```python
# Q = np.array([[0, 1], [1, 0]])  # Example: permutation matrix
#
# is_orthogonal = np.allclose(Q.T @ Q, np.eye(Q.shape[0]))  # Check if Q^T * Q = I
# print("Is Q orthogonal?", is_orthogonal)
# ```
#
# ### 4.3:
#
# ```python
# A = np.array([[1, 2, 3], [2, 5, 6], [3, 6, 9]])
#
# is_symmetric = np.allclose(A, A.T)  # Check if A is equal to its transpose
# print("Is A symmetric?", is_symmetric)
# ```
